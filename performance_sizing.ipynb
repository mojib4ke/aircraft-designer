# %%
from requirement import *

sea_level_density = 0.002377

points = [
    {
        'name': 'AT802',
        'wing loading': 10,
        'power loading': 10
    }
]

requirements = [
    {
        'name': 'clean stall speed',
        'type': RequirementType.STALL_SPEED,
        'stall speed': 70,
        'density': sea_level_density,
        'C_L_max': 1.2,
    },
    {
        'name': 'takeoff distance',
        'type': RequirementType.TAKEOFF_DISTANCE,
        'takeoff distance': 2000,
        'sigma': 1,
        'C_L_max_TO': 1.5,
    },
    {
        'name': 'landing distance',
        'type': RequirementType.LANDING_DISTANCE,
        'landing distance': 2000,
        'density': sea_level_density,
        'C_L_max_L': 1.9,
        'takeoff weight ratio': 0.9,
    },
]

performance_sizing = Requirement(requirements, points)
performance_sizing.loadings_plot()
